# %% [markdown]
# Install and Load **ggplot2**

# %%
install.packages("tidyverse")

install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
detach(package:ggplot2)

# %% [markdown]
# Basic Syntax of ggplot2

# %%
ggplot(data, aes(x, y)) + geom_function()

# %% [markdown]
# # **Common Graph Types**

# %% [markdown]
# Scatter Plot

# %%
library(ggplot2)
ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() +
  labs(title = "Scatter Plot of Weight vs MPG", x = "Weight", y = "Miles Per Gallon") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Histogram

# %%
ggplot(mtcars, aes(x = mpg)) +
  geom_histogram(binwidth = 2, fill = "skyblue", color = "black") +
  labs(title = "Histogram of Miles Per Gallon", x = "Miles Per Gallon", y = "Frequency") +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# Box Plot

# %%
ggplot(mtcars, aes(x = factor(cyl), y = mpg, fill = factor(cyl))) +
  geom_boxplot() +
  labs(title = "Boxplot of MPG by Cylinders", x = "Cylinders", y = "Miles Per Gallon") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Bar Chart

# %%
ggplot(mtcars, aes(x = factor(cyl))) +
  geom_bar(fill = "lightgreen", color = "black") +
  labs(title = "Bar Chart of Cylinder Counts", x = "Cylinders", y = "Count") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Pie Chart

# %%
library(dplyr)
data <- mtcars %>%
  count(cyl) %>%
  mutate(percent = n / sum(n) * 100)

ggplot(data, aes(x = "", y = percent, fill = factor(cyl))) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar("y") +
  labs(title = "Pie Chart of Cylinder Proportions", fill = "Cylinders") +
  theme_void()
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# plot without title

# %% [markdown]
# Density Plot

# %%
library(ggplot2)

ggplot(data = mtcars, aes(x = mpg)) +
  geom_density(fill = "lightblue", alpha = 0.5) +
  ggtitle("Density Plot of Distribution of Miles per Gallon") +
  xlab("Miles per Gallon") +
  ylab("Density")
# Out:
# plot without title

# %% [markdown]
# ## **Advanced Features**

# %% [markdown]
# Faceting

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() +
  facet_wrap(~cyl) +
  labs(title = "Scatter Plot Faceted by Cylinders") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Adding Trend Lines

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red") +
  labs(title = "Scatter Plot with Trend Line", x = "Weight", y = "Miles Per Gallon") +
  theme_classic()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
